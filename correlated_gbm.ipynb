# %%
import numpy as np
import gbm
import alpha_beta
import matplotlib.pyplot as plt

total_time = 1.0
sim_period = 0.001

n = int(np.round(total_time / float(sim_period))) # number of simulations
t = np.linspace(0, total_time, n)

MEAN = np.ones(shape=(1,2)) * 0.1
STDEV = np.ones(shape=(1,2)) * 0.16
corr_matrix = gbm.correl_matrix_from_corr(0.9)

#S = gbm.generate_brownian_motion(total_time, sim_period, 0.1, 0.16)
S = gbm.multi_generate_brownian_motion(total_time, sim_period, MEAN, STDEV, corr_matrix=corr_matrix)

# %matplotlib inline


plt.plot(t, S)
plt.show()
# Out:
# [[ 0.1  0.1]]
# [[ 0.16  0.16]]
# [[ 0.1  0.1]]
